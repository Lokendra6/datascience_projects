# %%
import pandas as pd
df=pd.read_csv("Temperature_forecast_project.csv")

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH    ...      \
# 0         28.074101         23.006936  6.818887   69.451805    ...
# 1         29.850689         24.035009  5.691890   51.937448    ...
# 2         30.091292         24.565633  6.138224   20.573050    ...
# 3         29.704629         23.326177  5.650050   65.727144    ...
# 4         29.113934         23.486480  5.735004  107.965535    ...
#
#    LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# ...

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
for i in df[['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
       'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
       'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
       'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
       'DEM', 'Slope', 'Solar radiation']]:
    if df[i].dtypes=="float64":
        df[i]=df[i].fillna(df[i].mean())

# %%
df.isnull().sum()
# Out:
# station              0
# Date                 2
# Present_Tmax         0
# Present_Tmin         0
# LDAPS_RHmin          0
# LDAPS_RHmax          0
# LDAPS_Tmax_lapse     0
# LDAPS_Tmin_lapse     0
# LDAPS_WS             0
# LDAPS_LH             0
# LDAPS_CC1            0
# LDAPS_CC2            0
# LDAPS_CC3            0
# LDAPS_CC4            0
# LDAPS_PPT1           0
# LDAPS_PPT2           0
# LDAPS_PPT3           0
# LDAPS_PPT4           0
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
df=df.dropna()
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
df_num=df.drop(columns=['Date','Next_Tmax','Next_Tmin'],axis=1)
import matplotlib.pyplot as plt
plt.figure(figsize=(20,25),facecolor="white")
plotnumber=1
for column in df_num:
    if plotnumber<=24:
        ax=plt.subplot(6,4,plotnumber)
        sns.distplot(df_num[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Python 2\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
t1=df["Next_Tmax"]
plt.figure(figsize=(20,30),facecolor="white")
plotnumber=1
for column in df_num:
    if plotnumber<=24:
        ax=plt.subplot(6,4,plotnumber)
        plt.scatter(df_num[column],t1)
        plt.xlabel(column,fontsize=20)
        plt.ylabel("Next_Tmax",fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
t1=df["Next_Tmin"]
plt.figure(figsize=(20,30),facecolor="white")
plotnumber=1
for column in df_num:
    if plotnumber<=24:
        ax=plt.subplot(6,4,plotnumber)
        plt.scatter(df_num[column],t1)
        plt.xlabel(column,fontsize=20)
        plt.ylabel("Next_Tmin",fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,25),facecolor="white")
plotnumber=1
for column in df_num:
    if plotnumber<=24:
        ax=plt.subplot(6,4,plotnumber)
        sns.boxplot(df_num[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
print(df["Date"].unique())
print(df["Date"].value_counts())
# Out:
# ['30-06-2013' '01-07-2013' '02-07-2013' '03-07-2013' '04-07-2013'
#  '05-07-2013' '06-07-2013' '07-07-2013' '08-07-2013' '09-07-2013'
#  '10-07-2013' '11-07-2013' '12-07-2013' '13-07-2013' '14-07-2013'
#  '15-07-2013' '16-07-2013' '17-07-2013' '18-07-2013' '19-07-2013'
#  '20-07-2013' '21-07-2013' '22-07-2013' '23-07-2013' '24-07-2013'
#  '25-07-2013' '26-07-2013' '27-07-2013' '28-07-2013' '29-07-2013'
#  '30-07-2013' '31-07-2013' '01-08-2013' '02-08-2013' '03-08-2013'
#  '04-08-2013' '05-08-2013' '06-08-2013' '07-08-2013' '08-08-2013'
#  '09-08-2013' '10-08-2013' '11-08-2013' '12-08-2013' '13-08-2013'
#  '14-08-2013' '15-08-2013' '16-08-2013' '17-08-2013' '18-08-2013'
#  '19-08-2013' '20-08-2013' '21-08-2013' '22-08-2013' '23-08-2013'
#  '24-08-2013' '25-08-2013' '26-08-2013' '27-08-2013' '28-08-2013'
#  '29-08-2013' '30-08-2013' '30-06-2014' '01-07-2014' '02-07-2014'
#  '03-07-2014' '04-07-2014' '05-07-2014' '06-07-2014' '07-07-2014'
# ...

# %%
df.corr()
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.113069      0.132188    -0.068285
# Present_Tmax      0.113069      1.000000      0.617749    -0.206945
# Present_Tmin      0.132188      0.617749      1.000000     0.120546
# LDAPS_RHmin      -0.068285     -0.206945      0.120546     1.000000
# LDAPS_RHmax      -0.168195     -0.304554     -0.018340     0.578708
# LDAPS_Tmax_lapse  0.070062      0.568925      0.462182    -0.568968
# LDAPS_Tmin_lapse  0.104919      0.623176      0.762386     0.086273
# LDAPS_WS          0.004444     -0.124895     -0.038291     0.291812
# LDAPS_LH         -0.132215      0.133118     -0.012656    -0.072808
# LDAPS_CC1         0.005876     -0.313528      0.083299     0.613201
# LDAPS_CC2         0.002184     -0.215106      0.088957     0.744980
# LDAPS_CC3        -0.000413     -0.144972     -0.004615     0.688652
# LDAPS_CC4         0.005160     -0.141378     -0.045932     0.512801
# ...

# %%
##for the correlation we can understand any particular feature do not have very strong correlation with Income
import matplotlib.pyplot as plt
plt.figure(figsize=(30,15))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black",fmt=".2f")

# %%
#from the above heatmap it can be identified
#Next_Tmax has strong positive correlation with Present_Tmax,Present_Tmin,LDAPS_Tmax_lapse,LDAPS_Tmin_lapse,Next_Tmin
#LNext_Tmax has strong negative correlation with DAPS_RHmin,LDAPS_CC1,LDAPS_CC2,LDAPS_CC3,LDAPS_CC

# %%
#from the above heatmap it can be identified
#Next_Tmin has strong positive correlation with Present_Tmax,Present_Tmin,LDAPS_Tmax_lapse,LDAPS_Tmin_lapse,Next_Tmin

# %%
y_tmax=df['Next_Tmax']
y_tmin=df["Next_Tmin"]

# %%
x=df.drop(columns=['Date','Next_Tmax','Next_Tmin'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x_new=scale.fit_transform(x)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#Identifying the best random state for Next_Tmin
#using the features(x_new) and target variable(y_tmin)
Maxr2_min=0
BestRs_min=0
for i in range(1,200):
    xtrain_tmin,xtest_tmin,ytrain_tmin,ytest_tmin=train_test_split(x_new,y_tmin,test_size=.20,random_state=i)
    lr=LinearRegression()
    lr.fit(xtrain_tmin,ytrain_tmin)
    pred=lr.predict(xtest_tmin)
    accu_min=r2_score(pred,ytest_tmin)
    if accu_min>Maxr2_min:
        Maxr2_min=accu_min
        BestRs_min=i
print("with random state as",BestRs_min,"max accuracy is",Maxr2_min)
# Out:
# with random state as 171 max accuracy is 0.8227245920406488

# %%
#Best random state for Next_Tmin is 171

# %%
#Identifying the best random state for Next_Tmax
#using the features(x_new) and target variable(y_tmax)
Maxr2_max=0
BestRs_max=0
for i in range(1,200):
    xtrain_tmax,xtest_tmax,ytrain_tmax,ytest_tmax=train_test_split(x_new,y_tmax,test_size=.20,random_state=i)
    lr=LinearRegression()
    lr.fit(xtrain_tmax,ytrain_tmax)
    pred=lr.predict(xtest_tmax)
    accu_max=r2_score(pred,ytest_tmax)
    if accu_max>Maxr2_max:
        Maxr2_max=accu_max
        BestRs_max=i
print("with random state as",BestRs_max,"max accuracy is",Maxr2_max)
# Out:
# with random state as 56 max accuracy is 0.7399211739614793

# %%
#Best random state for Next_Tmax is 56

# %%
#Now fitting the model using random state 56 for Next_Tmax
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

xtrain_max,xtest_max,ytrain_max,ytest_max=train_test_split(x_new,y_tmax,test_size=.20,random_state=56)
lr=LinearRegression()
lr.fit(xtrain_max,ytrain_max)
pred=lr.predict(xtest_max)
print("r_score for linear regression",r2_score(pred,ytest_max))
print("mean_squared_error for linear regression",mean_squared_error(pred,ytest_max))
print("mean_absolute_error for linear regression",mean_absolute_error(pred,ytest_max))
print("\n")
print("\n")
rfr=RandomForestRegressor()
rfr.fit(xtrain_max,ytrain_max)
pred=rfr.predict(xtest_max)
print("r_score for RandomForestRegressor",r2_score(pred,ytest_max))
print("mean_squared_error RandomForestRegressor",mean_squared_error(pred,ytest_max))
print("mean_absolute_error for RandomForestRegressor",mean_absolute_error(pred,ytest_max))
print("\n")
print("\n")
svr=SVR()
svr.fit(xtrain_max,ytrain_max)
pred=svr.predict(xtest_max)
print("r_score for Supportvector Regressor",r2_score(pred,ytest_max))
print("mean_squared_error for Supportvector Regressor",mean_squared_error(pred,ytest_max))
print("mean_absolute_error for Supportvector Regressor",mean_absolute_error(pred,ytest_max))
print("\n")
print("\n")
dtr=DecisionTreeRegressor()
dtr.fit(xtrain_max,ytrain_max)
pred=dtr.predict(xtest_max)
print("r_score for DecisionTreeRegressor",r2_score(pred,ytest_max))
print("mean_squared_error for DecisionTreeRegressor",mean_squared_error(pred,ytest_max))
print("mean_absolute_error for DecisionTreeRegressor",mean_absolute_error(pred,ytest_max))
# Out:
# r_score for linear regression 0.7399211739614793
# mean_squared_error for linear regression 2.114859752901935
# mean_absolute_error for linear regression 1.104157013787228
#
#
#
#
# r_score for RandomForestRegressor 0.8981250212760558
# mean_squared_error RandomForestRegressor 0.8978788970873782
# mean_absolute_error for RandomForestRegressor 0.6992595469255665
#
#
#
#
# r_score for Supportvector Regressor 0.8425310118691991
# mean_squared_error for Supportvector Regressor 1.2981872010035227
# mean_absolute_error for Supportvector Regressor 0.8286231312128343
#
#
#
#
# r_score for DecisionTreeRegressor 0.8149204325575401
# mean_squared_error for DecisionTreeRegressor 1.9369838187702269
# mean_absolute_error for DecisionTreeRegressor 0.9703559870550162

# %%
#using cross validation to check for over-fitting for target variable(Next_Tmax)
from sklearn.model_selection import cross_val_score
model=[lr,rfr,svr,dtr]
for model in model:
    print(cross_val_score(model,x_new,y_tmax,cv=5).mean())
# Out:
# 0.7064185006831194
# 0.6904088470781437
# 0.6766545080025114
# 0.4323672373005653

# %%
#Now fitting the model using random state 56 for Next_Tmin
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

xtrain_min,xtest_min,ytrain_min,ytest_min=train_test_split(x_new,y_tmin,test_size=.20,random_state=171)
lr=LinearRegression()
lr.fit(xtrain_min,ytrain_min)
pred=lr.predict(xtest_min)
print("r_score for linear regression",r2_score(pred,ytest_min))
print("mean_squared_error for linear regression",mean_squared_error(pred,ytest_min))
print("mean_absolute_error for linear regression",mean_absolute_error(pred,ytest_min))
print("\n")
print("\n")
rfr=RandomForestRegressor()
rfr.fit(xtrain_min,ytrain_min)
pred=rfr.predict(xtest_min)
print("r_score for RandomForestRegressor",r2_score(pred,ytest_min))
print("mean_squared_error RandomForestRegressor",mean_squared_error(pred,ytest_min))
print("mean_absolute_error for RandomForestRegressor",mean_absolute_error(pred,ytest_min))
print("\n")
print("\n")
svr=SVR()
svr.fit(xtrain_min,ytrain_min)
pred=svr.predict(xtest_min)
print("r_score for Supportvector Regressor",r2_score(pred,ytest_min))
print("mean_squared_error for Supportvector Regressor",mean_squared_error(pred,ytest_min))
print("mean_absolute_error for Supportvector Regressor",mean_absolute_error(pred,ytest_min))
print("\n")
print("\n")
dtr=DecisionTreeRegressor()
dtr.fit(xtrain_min,ytrain_min)
pred=dtr.predict(xtest_min)
print("r_score for DecisionTreeRegressor",r2_score(pred,ytest_min))
print("mean_squared_error for DecisionTreeRegressor",mean_squared_error(pred,ytest_min))
print("mean_absolute_error for DecisionTreeRegressor",mean_absolute_error(pred,ytest_min))
# Out:
# r_score for linear regression 0.8227245920406488
# mean_squared_error for linear regression 0.9202913469292907
# mean_absolute_error for linear regression 0.7525854316957166
#
#
#
#
# r_score for RandomForestRegressor 0.9038377416792972
# mean_squared_error RandomForestRegressor 0.5200967669902913
# mean_absolute_error for RandomForestRegressor 0.5534789644012945
#
#
#
#
# r_score for Supportvector Regressor 0.8904086514947455
# mean_squared_error for Supportvector Regressor 0.5726368301381688
# mean_absolute_error for Supportvector Regressor 0.5686931952472261
#
#
#
#
# r_score for DecisionTreeRegressor 0.7910078079909713
# mean_squared_error for DecisionTreeRegressor 1.3162783171521035
# mean_absolute_error for DecisionTreeRegressor 0.8479611650485437

# %%
from sklearn.model_selection import cross_val_score
model=[lr,rfr,svr,dtr]
for model in model:
    print(cross_val_score(model,x_new,y_tmin,cv=5).mean())
# Out:
# 0.7784700038579349
# 0.7775088866217233
# 0.7293404016218185
# 0.5750866853806582

# %%
##for both y_tmax(Next_Tmax) and y_tmin(Next_Tmin),linear regression is the best model to proceed
##from r2_score and cross_val_score it can be deducted that linear regression is the best model to proceed
##As difference between r2_score and cross_val_score is minimum in case of linear regression

# %%
#Now parameter tuning for y_tmax(Next_Tmax) using GridSearchCV
import numpy as np
from sklearn.model_selection import GridSearchCV
parameter={"fit_intercept":[True,False],"normalize":[True,False],"n_jobs":np.arange(2,10),"positive":[True,False]}
grid=GridSearchCV(estimator=lr,param_grid=parameter,cv=5)
grid.fit(xtrain_max,ytrain_max)
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.7602353774824728
# {'fit_intercept': True, 'n_jobs': 2, 'normalize': True, 'positive': False}

# %%
#Now parameter tuning for y_tmin(Next_Tmin) using GridSearchCV
from sklearn.model_selection import GridSearchCV
parameter={"fit_intercept":[True,False],"normalize":[True,False],"n_jobs":np.arange(2,10),"positive":[True,False]}
grid=GridSearchCV(estimator=lr,param_grid=parameter,cv=5)
grid.fit(xtrain_min,ytrain_min)
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.8259253342284166
# {'fit_intercept': True, 'n_jobs': 2, 'normalize': True, 'positive': False}

# %%
#from the grid search it can be identied that what are the best parameters for y_tmax(Next_Tmax)
#{'fit_intercept': True, 'n_jobs': 2, 'normalize': True, 'positive': False}
#Now parameters can be used to develop final model for y_tmax(Next_Tmax)

finallrmax=LinearRegression(fit_intercept=True,n_jobs=2,normalize=True,positive=False)
finallrmax.fit(xtrain_max,ytrain_max)
pred=finallrmax.predict(xtest_max)
print(r2_score(pred,ytest_max))
# Out:
# 0.7399211739614798

# %%
#from the grid search it can be identied that what are the best parameters for y_tmax(Next_Tmax)
#{'fit_intercept': True, 'n_jobs': 2, 'normalize': True, 'positive': False}
#Now parameters can be used to develop final model for y_tmax(Next_Tmax)

finallrmin=LinearRegression(fit_intercept=True,n_jobs=2,normalize=True,positive=False)
finallrmin.fit(xtrain_min,ytrain_min)
pred=finallrmin.predict(xtest_min)
print(r2_score(pred,ytest_min))
# Out:
# 0.8227245920406487

# %%
#Saving the model for y_tmax(Next_Tmax)
import joblib
joblib.dump(finallrmax,"Temperature_pred_tmax.obj")
# Out:
# ['Temperature_pred_tmax.obj']

# %%
#Saving the model for y_tmin(Next_Tmin)
import joblib
joblib.dump(finallrmin,"Temperature_pred_tmin.obj")
# Out:
# ['Temperature_pred_tmin.obj']
